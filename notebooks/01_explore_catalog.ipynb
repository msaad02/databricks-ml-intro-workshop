# %% [markdown]
# # 1. Find the data in Unity Catalog
# We use the free `samples` catalog that ships with every workspace. No setup, no ingestion.
#
# **Concepts:** Unity Catalog, three-level namespace (`catalog.schema.table`), notebook + SQL.

# %%
# %sql
-- Browse the catalog the same way the UI Catalog Explorer does.
SHOW TABLES IN samples.nyctaxi

# %%
# %sql
-- Peek at the data we'll model: NYC taxi trips.
SELECT * FROM samples.nyctaxi.trips LIMIT 10

# %% [markdown]
# > **Expand here:** point Genie at `samples.nyctaxi.trips` for natural-language Q&A, or explore lineage and tags in Catalog Explorer.
